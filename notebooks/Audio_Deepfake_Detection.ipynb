# %% [markdown]
# # Audio Deepfake Detection
#
# This notebook explores binary classification of authentic and AI-generated speech using spectral audio features and supervised machine learning models.

# %% [markdown]
# ## 1. Setup
#
# Import libraries, configure paths, and load helper modules from `src/`.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent
sys.path.append(str(PROJECT_ROOT / "src"))

DATA_DIR = PROJECT_ROOT / "data"
RESULTS_DIR = PROJECT_ROOT / "results"

# %% [markdown]
# ## 2. Data Loading
#
# Download the Fake-or-Real Audio Dataset from Kaggle and place it in the local `data/` directory before running the full workflow.

# %%
# Example placeholder for collecting labeled audio paths.
# real_files = list((DATA_DIR / "real").glob("*.wav"))
# fake_files = list((DATA_DIR / "fake").glob("*.wav"))

# %% [markdown]
# ## 3. Preprocessing and Feature Extraction
#
# Load audio, remove silence, pad or trim clips, and extract spectral feature summaries.

# %%
# from preprocessing import load_audio, remove_silence, pad_or_trim
# from feature_extraction import extract_audio_features

# %% [markdown]
# ## 4. Model Training
#
# Train and compare Logistic Regression, kNN, Gaussian Naive Bayes, and MLP classifiers.

# %%
# from train import train_and_compare
# metrics = train_and_compare(features, labels)

# %% [markdown]
# ## 5. Evaluation
#
# Evaluate performance using accuracy, precision, recall, F1-score, and confusion matrices.

# %%
# from evaluate import plot_confusion_matrix, plot_model_comparison
# plot_model_comparison(metrics, RESULTS_DIR / "model_comparison.png")
